# %%
# Importing necessary packages
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("whitegrid")
sns.set_context("poster")
c0=sns.color_palette()[0]
c1=sns.color_palette()[1]
c2=sns.color_palette()[2]

# %%
# Uploading Dataset and inspecting its contents
df = pd.DataFrame()
df = pd.read_csv('/Users/dwreiter/Desktop/Work/Springboard/Video Game Capstone Project/Data Wrangling/vg_df.csv', delimiter='\t', index_col=0)
df.head()
# Out:
#                       Platform  Year_of_Release     Genre Publisher  NA_Sales  \
# Name
# Wii Sports                 Wii             2006    Sports  Nintendo     41.36
# Mario Kart Wii             Wii             2008    Racing  Nintendo     15.68
# Wii Sports Resort          Wii             2009    Sports  Nintendo     15.61
# New Super Mario Bros.       DS             2006  Platform  Nintendo     11.28
# Wii Play                   Wii             2006      Misc  Nintendo     13.96
#
#                        EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# Name
# Wii Sports                28.96      3.77         8.45         82.53
# Mario Kart Wii            12.76      3.79         3.29         35.52
# Wii Sports Resort         10.93      3.28         2.95         32.77
# New Super Mario Bros.      9.14      6.50         2.88         29.80
# Wii Play                   9.18      2.93         2.84         28.92
#
# ...

# %%
# Plotting Genre vs Global Sales
_ = plt.scatter(df['Genre'], df['Global_Sales'])
_ = plt.grid(False)
_ = plt.xticks(rotation=40)
_ = plt.xlabel('Genre')
_ = plt.ylabel('Sales (Millions)')
_ = plt.title('Genre vs Global Sales')

# %%
# Plotting Genre vs Regional Sale
_ = plt.scatter(df['Genre'], df['NA_Sales'], label='North America')
_ = plt.scatter(df['Genre'], df['EU_Sales'], label='Europe')
_ = plt.scatter(df['Genre'], df['JP_Sales'], label='Japan')
_ = plt.grid(False)
_ = plt.xticks(rotation=40)
_ = plt.xlabel('Genre')
_ = plt.ylabel('Sales (Millions)')
_ = plt.legend(loc='upper right')
_ = plt.title('Genre vs Regional Sales')

# %%
# Plotting Sports Games vs North American Sales
_ = sns.barplot(x=df['Sports'], y=df['NA_Sales'], data=df)
_ = plt.title('Sports Games vs North American Sales')

# %%
# Plotting Sports Games vs European Sales
_ = sns.barplot(x=df['Sports'], y=df['EU_Sales'], data=df)
_ = plt.title('Sports Games vs European Sales')

# %%
# Plotting Sports Games vs Japanese Sales
_ = sns.barplot(x=df['Sports'], y=df['JP_Sales'], data=df)
_ = plt.title('Sports Games vs Japanese Sales')

# %%
# Plotting Racing Games vs North American Sales
_ = sns.barplot(x=df['Racing'], y=df['NA_Sales'], data=df)
_ = plt.title('Racing Games vs North American Sales')

# %%
# Plotting Racing Games vs European Sales
_ = sns.barplot(x=df['Racing'], y=df['EU_Sales'], data=df)
_ = plt.title('Racing Games vs European Sales')

# %%
# Plotting Racing Games vs Japanese Sales
_ = sns.barplot(x=df['Racing'], y=df['JP_Sales'], data=df)
_ = plt.title('Racing Games vs Japanese Sales')

# %%
# Plotting Platformers vs North American Sales
_ = sns.barplot(x=df['Platformer'], y=df['NA_Sales'], data=df)
_ = plt.title('Platformers vs North American Sales')

# %%
# Plotting Platformers vs European Sales
_ = sns.barplot(x=df['Platformer'], y=df['EU_Sales'], data=df)
_ = plt.title('Platformers vs European Sales')

# %%
# Plotting Platformers vs Japanese Sales
_ = sns.barplot(x=df['Platformer'], y=df['JP_Sales'], data=df)
_ = plt.title('Platformers vs Japanese Sales')

# %%
# Plotting Variety Games (Misc.) vs North American Sales
_ = sns.barplot(x=df['Variety'], y=df['NA_Sales'], data=df)
_ = plt.title('Variety (Misc.) Games vs North American Sales')

# %%
# Plotting Variety Games (Misc.) vs European Sales
_ = sns.barplot(x=df['Variety'], y=df['EU_Sales'], data=df)
_ = plt.title('Variety (Misc.) Games vs European Sales')

# %%
# Plotting Variety Games (Misc.) vs Japanese Sales
_ = sns.barplot(x=df['Variety'], y=df['JP_Sales'], data=df)
_ = plt.title('Variety (Misc.) Games vs Japanese Sales')

# %%
# Plotting Action Games vs North American Sales
_ = sns.barplot(x=df['Action'], y=df['NA_Sales'], data=df)
_ = plt.title('Action Games vs North American Sales')

# %%
# Plotting Action Games vs European Sales
_ = sns.barplot(x=df['Action'], y=df['EU_Sales'], data=df)
_ = plt.title('Action Games vs European Sales')

# %%
# Plotting Action Games vs Japanese Sales
_ = sns.barplot(x=df['Action'], y=df['JP_Sales'], data=df)
_ = plt.title('Action Games vs Japanese Sales')

# %%
# Plotting Puzzle Games vs North American Sales
_ = sns.barplot(x=df['Puzzler'], y=df['NA_Sales'], data=df)
_ = plt.title('Puzzle Games vs North American Sales')

# %%
# Plotting Puzzle Games vs European Sales
_ = sns.barplot(x=df['Puzzler'], y=df['EU_Sales'], data=df)
_ = plt.title('Puzzle Games vs European Sales')

# %%
# Plotting Puzzle Games vs Japanese Sales
_ = sns.barplot(x=df['Puzzler'], y=df['JP_Sales'], data=df)
_ = plt.title('Puzzle Games vs Japanese Sales')

# %%
# Plotting Shooting Games vs North American Sales
_ = sns.barplot(x=df['Shooter'], y=df['NA_Sales'], data=df)
_ = plt.title('Shooting Games vs North American Sales')

# %%
# Plotting Shooting Games vs European Sales
_ = sns.barplot(x=df['Shooter'], y=df['EU_Sales'], data=df)
_ = plt.title('Shooting Games vs European Sales')

# %%
# Plotting Shooting Games vs Japanese Sales
_ = sns.barplot(x=df['Shooter'], y=df['JP_Sales'], data=df)
_ = plt.title('Shooting Games vs Japanese Sales')

# %%
# Plotting Fighting Games vs North American Sales
_ = sns.barplot(x=df['Fighter'], y=df['NA_Sales'], data=df)
_ = plt.title('Fighting Games vs North American Sales')

# %%
# Plotting Fighting Games vs European Sales
_ = sns.barplot(x=df['Fighter'], y=df['EU_Sales'], data=df)
_ = plt.title('Fighting Games vs European Sales')

# %%
# Plotting Fighting Games vs Japanese Sales
_ = sns.barplot(x=df['Fighter'], y=df['JP_Sales'], data=df)
_ = plt.title('Fighting Games vs Japanese Sales')

# %%
# Plotting Simulation Games vs North American Sales
_ = sns.barplot(x=df['Simulation'], y=df['NA_Sales'], data=df)
_ = plt.title('Simulation Games vs North American Sales')

# %%
# Plotting Simulation Games vs European Sales
_ = sns.barplot(x=df['Simulation'], y=df['EU_Sales'], data=df)
_ = plt.title('Simulation Games vs European Sales')

# %%
# Plotting Simulation Games vs Japanese Sales
_ = sns.barplot(x=df['Simulation'], y=df['JP_Sales'], data=df)
_ = plt.title('Simulation Games vs Japanese Sales')

# %%
# Plotting Role-Playing Games vs North American Sales
_ = sns.barplot(x=df['RPG'], y=df['NA_Sales'], data=df)
_ = plt.title('Role-Playing Games vs North American Sales')

# %%
# Plotting Role-Playing Games vs European Sales
_ = sns.barplot(x=df['RPG'], y=df['EU_Sales'], data=df)
_ = plt.title('Role-Playing Games vs European Sales')

# %%
# Plotting Role-Playing Games vs Japanese Sales
_ = sns.barplot(x=df['RPG'], y=df['JP_Sales'], data=df)
_ = plt.title('Role-Playing Games vs Japanese Sales')

# %%
# Plotting Adventure Games vs North American Sales
_ = sns.barplot(x=df['Adventure'], y=df['NA_Sales'], data=df)
_ = plt.title('Adventure Games vs North American Sales')

# %%
# Plotting Adventure Games vs European Sales
_ = sns.barplot(x=df['Adventure'], y=df['EU_Sales'], data=df)
_ = plt.title('Adventure Games vs European Sales')

# %%
# Plotting Adventure Games vs Japanese Sales
_ = sns.barplot(x=df['Adventure'], y=df['JP_Sales'], data=df)
_ = plt.title('Adventure Games vs Japanese Sales')

# %%
# Plotting Strategy Games vs North American Sales
_ = sns.barplot(x=df['Strategy'], y=df['NA_Sales'], data=df)
_ = plt.title('Strategy Games vs North American Sales')

# %%
# Plotting Strategy Games vs European Sales
_ = sns.barplot(x=df['Strategy'], y=df['EU_Sales'], data=df)
_ = plt.title('Strategy Games vs European Sales')

# %%
# Plotting Strategy Games vs Japanese Sales
_ = sns.barplot(x=df['Strategy'], y=df['JP_Sales'], data=df)
_ = plt.title('Strategy Games vs Japanese Sales')

# %%
# Plotting Platform vs Global Sales
_ = plt.scatter(df['Platform'], df['Global_Sales'])
_ = plt.grid(False)
_ = plt.xticks(rotation=40)
_ = plt.xlabel('Platform')
_ = plt.ylabel('Sales (Millions)')
_ = plt.title('Platform vs Global Sales')

# %%
# Plotting Platform vs Regional Sales
_ = plt.scatter(df['Platform'], df['NA_Sales'], label='North America')
_ = plt.scatter(df['Platform'], df['EU_Sales'], label='Europe')
_ = plt.scatter(df['Platform'], df['JP_Sales'], label='Japan')
_ = plt.grid(False)
_ = plt.xticks(rotation=40)
_ = plt.xlabel('Platform')
_ = plt.ylabel('Sales (Millions)')
_ = plt.legend(loc='upper right')
_ = plt.title('Platform vs Regional Sales')

# %%
# Plotting Wii Games vs North American Sales
_ = sns.barplot(x=df['Nintendo Wii'], y=df['NA_Sales'], data=df)
_ = plt.title('Wii Games vs North American Sales')

# %%
# Plotting Wii Games vs European Sales
_ = sns.barplot(x=df['Nintendo Wii'], y=df['EU_Sales'], data=df)
_ = plt.title('Wii Games vs European Sales')

# %%
# Plotting Wii Games vs Japanese Sales
_ = sns.barplot(x=df['Nintendo Wii'], y=df['JP_Sales'], data=df)
_ = plt.title('Wii Games vs Japanese Sales')

# %%
# Plotting DS Games vs North American Sales
_ = sns.barplot(x=df['Nintendo DS'], y=df['NA_Sales'], data=df)
_ = plt.title('DS Games vs North American Sales')

# %%
# Plotting DS Games vs European Sales
_ = sns.barplot(x=df['Nintendo DS'], y=df['EU_Sales'], data=df)
_ = plt.title('DS Games vs European Sales')

# %%
# Plotting DS Games vs Japanese Sales
_ = sns.barplot(x=df['Nintendo DS'], y=df['JP_Sales'], data=df)
_ = plt.title('DS Games vs Japanese Sales')

# %%
# Plotting XBOX 360 Games vs North American Sales
_ = sns.barplot(x=df['XBOX 360'], y=df['NA_Sales'], data=df)
_ = plt.title('XBOX 360 Games vs North American Sales')

# %%
# Plotting XBOX 360 Games vs European Sales
_ = sns.barplot(x=df['XBOX 360'], y=df['EU_Sales'], data=df)
_ = plt.title('XBOX 360 Games vs European Sales')

# %%
# Plotting XBOX 360 Games vs Japanese Sales
_ = sns.barplot(x=df['XBOX 360'], y=df['JP_Sales'], data=df)
_ = plt.title('XBOX 360 Games vs Japanese Sales')

# %%
# Plotting PS3 Games vs North American Sales
_ = sns.barplot(x=df['Playstation 3'], y=df['NA_Sales'], data=df)
_ = plt.title('PS3 Games vs North American Sales')

# %%
# Plotting PS3 Games vs European Sales
_ = sns.barplot(x=df['Playstation 3'], y=df['EU_Sales'], data=df)
_ = plt.title('PS3 Games vs European Sales')

# %%
# Plotting PS3 Games vs Japanese Sales
_ = sns.barplot(x=df['Playstation 3'], y=df['JP_Sales'], data=df)
_ = plt.title('PS3 Games vs Japanese Sales')

# %%
# Plotting PS2 Games vs North American Sales
_ = sns.barplot(x=df['Playstation 2'], y=df['NA_Sales'], data=df)
_ = plt.title('PS2 Games vs North American Sales')

# %%
# Plotting PS2 Games vs European Sales
_ = sns.barplot(x=df['Playstation 2'], y=df['EU_Sales'], data=df)
_ = plt.title('PS2 Games vs European Sales')

# %%
# Plotting PS2 Games vs Japanese Sales
_ = sns.barplot(x=df['Playstation 2'], y=df['JP_Sales'], data=df)
_ = plt.title('PS2 Games vs Japanese Sales')

# %%
# Plotting 3DS Games vs North American Sales
_ = sns.barplot(x=df['Nintendo 3DS'], y=df['NA_Sales'], data=df)
_ = plt.title('3DS Games vs North American Sales')

# %%
# Plotting 3DS Games vs European Sales
_ = sns.barplot(x=df['Nintendo 3DS'], y=df['EU_Sales'], data=df)
_ = plt.title('3DS Games vs European Sales')

# %%
# Plotting 3DS Games vs Japanese Sales
_ = sns.barplot(x=df['Nintendo 3DS'], y=df['JP_Sales'], data=df)
_ = plt.title('3DS Games vs Japanese Sales')

# %%
# Plotting PS4 Games vs North American Sales
_ = sns.barplot(x=df['Playstation 4'], y=df['NA_Sales'], data=df)
_ = plt.title('PS4 Games vs North American Sales')

# %%
# Plotting PS4 Games vs European Sales
_ = sns.barplot(x=df['Playstation 4'], y=df['EU_Sales'], data=df)
_ = plt.title('PS4 Games vs European Sales')

# %%
# Plotting PS4 Games vs Japanese Sales
_ = sns.barplot(x=df['Playstation 4'], y=df['JP_Sales'], data=df)
_ = plt.title('PS4 Games vs Japanese Sales')

# %%
# Plotting Playstation Games vs North American Sales
_ = sns.barplot(x=df['Playstation'], y=df['NA_Sales'], data=df)
_ = plt.title('Playstation Games vs North American Sales')

# %%
# Plotting Playstation Games vs European Sales
_ = sns.barplot(x=df['Playstation'], y=df['EU_Sales'], data=df)
_ = plt.title('Playstation Games vs European Sales')

# %%
# Plotting Playstation Games vs Japanese Sales
_ = sns.barplot(x=df['Playstation'], y=df['JP_Sales'], data=df)
_ = plt.title('Playstation Games vs Japanese Sales')

# %%
# Plotting XBOX Games vs North American Sales
_ = sns.barplot(x=df['XBOX'], y=df['NA_Sales'], data=df)
_ = plt.title('XBOX Games vs North American Sales')

# %%
# Plotting XBOX Games vs European Sales
_ = sns.barplot(x=df['XBOX'], y=df['EU_Sales'], data=df)
_ = plt.title('XBOX Games vs European Sales')

# %%
# Plotting XBOX Games vs Japanese Sales
_ = sns.barplot(x=df['XBOX'], y=df['JP_Sales'], data=df)
_ = plt.title('XBOX Games vs Japanese Sales')

# %%
# Plotting PC Games vs North American Sales
_ = sns.barplot(x=df['PC'], y=df['NA_Sales'], data=df)
_ = plt.title('PC Games vs North American Sales')

# %%
# Plotting PC Games vs European Sales
_ = sns.barplot(x=df['PC'], y=df['EU_Sales'], data=df)
_ = plt.title('PC Games vs European Sales')

# %%
# Plotting PC Games vs Japanese Sales
_ = sns.barplot(x=df['PC'], y=df['JP_Sales'], data=df)
_ = plt.title('PC Games vs Japanese Sales')

# %%
# Plotting PSP Games vs North American Sales
_ = sns.barplot(x=df['PSP'], y=df['NA_Sales'], data=df)
_ = plt.title('PSP Games vs North American Sales')

# %%
# Plotting PSP Games vs European Sales
_ = sns.barplot(x=df['PSP'], y=df['EU_Sales'], data=df)
_ = plt.title('PSP Games vs European Sales')

# %%
# Plotting PSP Games vs Japanese Sales
_ = sns.barplot(x=df['PSP'], y=df['JP_Sales'], data=df)
_ = plt.title('PSP Games vs Japanese Sales')

# %%
# Plotting Wii U Games vs North American Sales
_ = sns.barplot(x=df['Nintendo Wii U'], y=df['NA_Sales'], data=df)
_ = plt.title('Wii U Games vs North American Sales')

# %%
# Plotting Wii U Games vs European Sales
_ = sns.barplot(x=df['Nintendo Wii U'], y=df['EU_Sales'], data=df)
_ = plt.title('Wii U Games vs European Sales')

# %%
# Plotting Wii U Games vs Japanese Sales
_ = sns.barplot(x=df['Nintendo Wii U'], y=df['JP_Sales'], data=df)
_ = plt.title('Wii U Games vs Japanese Sales')

# %%
# Plotting Gamecube Games vs North American Sales
_ = sns.barplot(x=df['Nintendo Gamecube'], y=df['NA_Sales'], data=df)
_ = plt.title('Gamecube Games vs North American Sales')

# %%
# Plotting Gamecube Games vs European Sales
_ = sns.barplot(x=df['Nintendo Gamecube'], y=df['EU_Sales'], data=df)
_ = plt.title('Gamecube Games vs European Sales')

# %%
# Plotting Gamecube Games vs Japanese Sales
_ = sns.barplot(x=df['Nintendo Gamecube'], y=df['JP_Sales'], data=df)
_ = plt.title('Gamecube Games vs Japanese Sales')

# %%
# Plotting GBA Games vs North American Sales
_ = sns.barplot(x=df['Game Boy Advance'], y=df['NA_Sales'], data=df)
_ = plt.title('GBA Games vs North American Sales')

# %%
# Plotting GBA Games vs European Sales
_ = sns.barplot(x=df['Game Boy Advance'], y=df['EU_Sales'], data=df)
_ = plt.title('GBA Games vs European Sales')

# %%
# Plotting GBA Games vs Japanese Sales
_ = sns.barplot(x=df['Game Boy Advance'], y=df['JP_Sales'], data=df)
_ = plt.title('GBA Games vs Japanese Sales')

# %%
# Plotting XBOX One Games vs North American Sales
_ = sns.barplot(x=df['XBOX One'], y=df['NA_Sales'], data=df)
_ = plt.title('XBOX One Games vs North American Sales')

# %%
# Plotting XBOX One Games vs European Sales
_ = sns.barplot(x=df['XBOX One'], y=df['EU_Sales'], data=df)
_ = plt.title('XBOX One Games vs European Sales')

# %%
# Plotting XBOX One Games vs Japanese Sales
_ = sns.barplot(x=df['XBOX One'], y=df['JP_Sales'], data=df)
_ = plt.title('XBOX One Games vs Japanese Sales')

# %%
# Plotting Playstation Vita Games vs North American Sales
_ = sns.barplot(x=df['Playstation Vita'], y=df['NA_Sales'], data=df)
_ = plt.title('Playstation Vita Games vs North American Sales')

# %%
# Plotting Playstation Vita Games vs European Sales
_ = sns.barplot(x=df['Playstation Vita'], y=df['EU_Sales'], data=df)
_ = plt.title('Playstation Vita Games vs European Sales')

# %%
# Plotting Playstation Vita Games vs Japanese Sales
_ = sns.barplot(x=df['Playstation Vita'], y=df['JP_Sales'], data=df)
_ = plt.title('Playstation Vita Games vs Japanese Sales')

# %%
# Plotting Dreamcast Games vs North American Sales
_ = sns.barplot(x=df['Sega Dreamcast'], y=df['NA_Sales'], data=df)
_ = plt.title('Dreamcast Games vs North American Sales')

# %%
# Plotting Dreamcast Games vs European Sales
_ = sns.barplot(x=df['Sega Dreamcast'], y=df['EU_Sales'], data=df)
_ = plt.title('Dreamcast Games vs European Sales')

# %%
# Plotting Dreamcast Games vs Japanese Sales
_ = sns.barplot(x=df['Sega Dreamcast'], y=df['JP_Sales'], data=df)
_ = plt.title('Dreamcast Games vs Japanese Sales')

# %%
# Plotting Critic Score vs Global Sales
_ = plt.scatter(df['Critic_Score'], df['Global_Sales'])
_ = plt.xlabel('Critic Score')
_ = plt.ylabel('Sales (Millions)')
_ = plt.title('Critic Score vs Global Sales')

# %%
# Plotting Critic Score vs Regional Sales
_ = plt.scatter(df['Critic_Score'], df['NA_Sales'], label='North America')
_ = plt.scatter(df['Critic_Score'], df['EU_Sales'], label='Europe')
_ = plt.scatter(df['Critic_Score'],df['JP_Sales'],  label='Japan')
_ = plt.xlabel('Critic Score')
_ = plt.ylabel('Sales (Millions)')
_ = plt.legend(loc='upper left')
_ = plt.title('Critic Score vs Regional Sales')

# %%
# Plotting User Score vs Global Sales
_ = plt.scatter(df['User_Score'], df['Global_Sales'])
_ = plt.xlabel('User Score')
_ = plt.ylabel('Sales (Millions)')
_ = plt.title('User Score vs Global Sales')

# %%
# Plotting User Score vs Regional Sales
_ = plt.scatter(df['User_Score'], df['NA_Sales'], label='North America')
_ = plt.scatter(df['User_Score'], df['EU_Sales'], label='Europe')
_ = plt.scatter(df['User_Score'],df['JP_Sales'],  label='Japan')
_ = plt.xlabel('User Score')
_ = plt.ylabel('Sales (Millions)')
_ = plt.legend(loc='upper left')
_ = plt.title('User Score vs Regional Sales')

# %%
# Plotting ESRB Rating vs Global Sales
_ = plt.scatter(df['Rating'], df['Global_Sales'])
_ = plt.grid(False)
_ = plt.xlabel('ESRB Rating')
_ = plt.ylabel('Sales (Millions)')
_ = plt.title('ESRB Rating vs Global Sales')

# %%
# Plotting ESRB Rating vs Regional Sales
_ = plt.scatter(df['Rating'], df['NA_Sales'], label='North America')
_ = plt.scatter(df['Rating'], df['EU_Sales'], label='Europe')
_ = plt.scatter(df['Rating'], df['JP_Sales'], label='Japan')
_ = plt.grid(False)
_ = plt.xlabel('ESRB Rating')
_ = plt.ylabel('Sales (Millions)')
_ = plt.legend(loc='upper right')
_ = plt.title('ESRB Rating vs Regional Sales')
